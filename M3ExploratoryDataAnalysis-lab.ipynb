# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify the distribution of data in the dataset.
#
# *   Identify outliers in the dataset.
#
# *   Remove outliers from the dataset.
#
# *   Identify correlation between features in the dataset.

# %% [markdown]
# ***

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
import seaborn as sns
ax = sns.distplot(df['ConvertedComp'], hist=False)

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
import matplotlib.pyplot as plt

# %%
plt.hist(df['ConvertedComp'],bins=200,color='#0504aa',alpha=0.7,rwidth=0.70)
# Out:
# (array([9.670e+02, 1.087e+03, 8.490e+02, 8.540e+02, 8.670e+02, 8.310e+02,
#         7.870e+02, 6.600e+02, 5.570e+02, 4.670e+02, 3.980e+02, 2.900e+02,
#         2.680e+02, 2.110e+02, 1.580e+02, 1.670e+02, 1.010e+02, 5.600e+01,
#         5.400e+01, 3.000e+01, 4.700e+01, 2.100e+01, 1.800e+01, 2.000e+01,
#         1.000e+01, 2.300e+01, 6.000e+00, 1.000e+01, 5.000e+00, 2.000e+00,
#         1.900e+01, 7.000e+00, 6.000e+00, 2.000e+00, 7.000e+00, 5.000e+00,
#         6.000e+00, 1.100e+01, 7.000e+00, 6.000e+00, 9.000e+00, 1.000e+01,
#         7.000e+00, 4.000e+00, 2.000e+00, 1.000e+01, 3.000e+00, 4.000e+00,
#         1.200e+01, 4.000e+00, 5.000e+00, 1.000e+00, 3.000e+00, 6.000e+00,
#         1.100e+01, 2.000e+00, 4.000e+00, 7.000e+00, 3.000e+00, 8.000e+00,
#         9.000e+00, 8.000e+00, 1.100e+01, 4.000e+00, 6.000e+00, 1.400e+01,
#         1.000e+00, 2.000e+00, 9.000e+00, 5.000e+00, 1.000e+01, 3.000e+00,
#         6.000e+00, 2.000e+00, 3.000e+00, 1.100e+01, 4.000e+00, 1.000e+00,
#         1.200e+01, 4.000e+00, 3.000e+00, 3.000e+00, 1.100e+01, 2.000e+00,
#         7.000e+00, 7.000e+00, 1.000e+01, 3.000e+00, 2.000e+00, 2.000e+00,
#         0.000e+00, 1.000e+00, 4.000e+00, 4.000e+00, 8.000e+00, 3.000e+00,
#         1.800e+01, 2.000e+00, 3.000e+00, 6.000e+00, 1.050e+02, 1.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 1.000e+00, 0.000e+00,
#         6.000e+00, 0.000e+00, 3.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         3.000e+00, 1.000e+00, 4.000e+00, 3.000e+00, 0.000e+00, 0.000e+00,
#         9.000e+00, 0.000e+00, 2.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         4.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.400e+01, 0.000e+00, 0.000e+00, 1.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         7.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         5.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         3.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         5.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         1.000e+00, 3.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         5.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 3.000e+00, 1.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         1.000e+00, 1.380e+02]),
#  array([      0.,   10000.,   20000.,   30000.,   40000.,   50000.,
#           60000.,   70000.,   80000.,   90000.,  100000.,  110000.,
#          120000.,  130000.,  140000.,  150000.,  160000.,  170000.,
#          180000.,  190000.,  200000.,  210000.,  220000.,  230000.,
#          240000.,  250000.,  260000.,  270000.,  280000.,  290000.,
#          300000.,  310000.,  320000.,  330000.,  340000.,  350000.,
#          360000.,  370000.,  380000.,  390000.,  400000.,  410000.,
#          420000.,  430000.,  440000.,  450000.,  460000.,  470000.,
#          480000.,  490000.,  500000.,  510000.,  520000.,  530000.,
#          540000.,  550000.,  560000.,  570000.,  580000.,  590000.,
#          600000.,  610000.,  620000.,  630000.,  640000.,  650000.,
#          660000.,  670000.,  680000.,  690000.,  700000.,  710000.,
#          720000.,  730000.,  740000.,  750000.,  760000.,  770000.,
#          780000.,  790000.,  800000.,  810000.,  820000.,  830000.,
#          840000.,  850000.,  860000.,  870000.,  880000.,  890000.,
#          900000.,  910000.,  920000.,  930000.,  940000.,  950000.,
#          960000.,  970000.,  980000.,  990000., 1000000., 1010000.,
#         1020000., 1030000., 1040000., 1050000., 1060000., 1070000.,
#         1080000., 1090000., 1100000., 1110000., 1120000., 1130000.,
#         1140000., 1150000., 1160000., 1170000., 1180000., 1190000.,
#         1200000., 1210000., 1220000., 1230000., 1240000., 1250000.,
#         1260000., 1270000., 1280000., 1290000., 1300000., 1310000.,
#         1320000., 1330000., 1340000., 1350000., 1360000., 1370000.,
#         1380000., 1390000., 1400000., 1410000., 1420000., 1430000.,
#         1440000., 1450000., 1460000., 1470000., 1480000., 1490000.,
#         1500000., 1510000., 1520000., 1530000., 1540000., 1550000.,
#         1560000., 1570000., 1580000., 1590000., 1600000., 1610000.,
#         1620000., 1630000., 1640000., 1650000., 1660000., 1670000.,
#         1680000., 1690000., 1700000., 1710000., 1720000., 1730000.,
#         1740000., 1750000., 1760000., 1770000., 1780000., 1790000.,
#         1800000., 1810000., 1820000., 1830000., 1840000., 1850000.,
#         1860000., 1870000., 1880000., 1890000., 1900000., 1910000.,
#         1920000., 1930000., 1940000., 1950000., 1960000., 1970000.,
#         1980000., 1990000., 2000000.]),
#  <BarContainer object of 200 artists>)

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df['ConvertedComp'].median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df['Gender'].value_counts()
# Out:
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
df[df['Gender'] == 'Woman']['ConvertedComp'].median()
# Out:
# 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df['Age'].describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
plt.hist(df['Age'],bins=200,color='#0504aa',alpha=0.7,rwidth=0.70)
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
ax = sns.boxplot(x=df['ConvertedComp'])

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
IQR = df['ConvertedComp'].quantile(0.75) - df['ConvertedComp'].quantile(0.25)
IQR
# Out:
# 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
Ubound = df['ConvertedComp'].quantile(0.75) + 1.5*IQR
Ubound
# Out:
# 209698.0

# %%
Lbound = df['ConvertedComp'].quantile(0.25) - 1.5*IQR
Lbound = max(Lbound, df['ConvertedComp'].min())
Lbound
# Out:
# 0.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
len(df[df['ConvertedComp'] > Ubound])
# Out:
# 879

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
df2 = df[df['ConvertedComp'] <= Ubound]
# Out:
# 52704.0

# %%
df2['ConvertedComp'].median()
df2['ConvertedComp'].mean()
# Out:
# 59883.20838915799

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
